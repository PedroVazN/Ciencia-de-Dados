# %% [markdown]
# #Isso é um título de nível 1

# %% [markdown]
# teste

# %% [markdown]
# ##Isso é um título de nível 2

# %% [markdown]
# ###Isso é um título de nível 3

# %% [markdown]
# #Primeiro Programa

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
#entrada de dados
lado1 = int(input("Digite a largura do terreno: "))
lado2 = int(input("Digite o comprimento do terreno: "))

#cálculo da área
area = (lado1*lado2)

#exibição da área
print(f"A área do terreno de largura: {lado1} com comprimento {lado2} é: {area}")
# Out:
# Digite a largura do terreno: 12
# Digite o comprimento do terreno: 30
# A área do terreno de largura: 12 com comprimento 30 é: 360
